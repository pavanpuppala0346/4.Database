# %% [markdown]
# ### 1.introduction to db's

# %% [markdown]
# ### 2.why SQL

# %% [markdown]
# ### 3.how sql statement executed

# %% [markdown]
# ### 4.imdb dataset

# %%
from PIL import Image
Image.open("E:/code/4.Databases/img/db.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1278x466 at 0x2BC70F4A9B0>

# %% [markdown]
# ### 5.Installation of MySql
# - Note: before you install XAMPP make sure you don't have any previously installed SQL versions installed in your system
# - 1. please download the XAMPP
#
# https://drive.google.com/file/d/1c_6C2Z26yKN1AhwArcGgLcZg_M81yAxF/view?usp=sharing
#
# - 2. please check the installation videos
#
# https://drive.google.com/file/d/1UH5tEiJoptGb8vGna7DiqyIV4ltpHGM9/view?usp=sharing

# %% [markdown]
# ### 6. load Imdb dataset
# - copy the file and save in a particular folder
# - open command line client --> enter password
#     - mysql>CREATE DATABASE imdb;
#     - mysql>USE imdb;
#     - mysql> SOURCE E:\code\4.Databases\data\imdb.sql;

# %% [markdown]
# ### 7.USE, DESCRIBE, SHOW TABLES
# - open command line client --> pasword
#     - mysql> USE <database_name>;
#     - mysql> SHOW TABLES;
#     - mysql> DESCRIBE <table_name>;

# %% [markdown]
# #### example

# %%
from PIL import Image
Image.open("E:/code/4.Databases/img/sql1.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=497x648 at 0x130CD906A20>

# %% [markdown]
# ### 8.SELECT
# - SELECT * FROM movies;
# #### more data transfer
# #### Result set:a set of rows that from the result set of a query along with column names and meta data
# - SELECT name, year FROM movies;
# - SELECT rankscore,name FROM movies;
# #### row order same as the one in the table

# %% [markdown]
# ### 9.LIMIT, OFFSET
# - SELECT name,rankscore FROM movies LIMIT 20;
# - SELECT name,rankscore FROM movies LIMIT 20 OFFSET 40;

# %% [markdown]
# ### 10.ORDER BY
# #### list recent movies first
# - SELECT name,rankscore,year FROM movies ORDER BY year DESC LIMIT 10;
#
# #### default order is ascending order
# - SELECT name,rankscore,year FROM movies ORDER BY year LIMIT 10;
#
# #### the output row order maynot be same as the one in the table due to query optimizer and internal data-structures/indices
