# %% [markdown]
# ### 6. Create Variables

# %%
from IPython.display import Image
Image("./img/sql9.png")

# %% [markdown]
# #### Pre requisites:  C language
# 1.	Variables
#     - Local Variables (User defined variables)
#     - Global Variables (System defined variables)
# 2.	If.. else
# 3.	loops (only while)
# 4.	print() function
# 5.	try catch blocks)
# 6.	Temp Tables
#     - Local temp tables
#     - Global temp tables
# 7. Table Variables
#
# - To centralize the data we use Table
# - To centralize (reusability of the code and security) the code we use Views, SP, UDF’s

# %% [markdown]
# <b>Variables:</b>
# - To store the data in RAM and move the data from one place to another place.
# - Variables are declared in the memory/RAM but not in SQL Server/Hard disk
# - There are 2 types of variables
#
# a)	Local Variables:
#
# -	These are created using ‘@’ symbol.
# -	Removed when the connection is closed.
# -	Who ever created them, They  can only use but not others
#
#
# Syntax:
