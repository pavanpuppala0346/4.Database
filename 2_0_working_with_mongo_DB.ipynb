# %% [markdown]
# #### diff between aql and no sql
# - SQL db is a Relational Database and a structured one
# - nosql is a non - relational database likely to be more document and distributed than structured
# - SQL db's are vertically scalable
# - NoSql db's are horizontally scalable

# %% [markdown]
# #### mongo db official:https://docs.atlas.mongodb.com/

# %%
#!pip install pymongo

# %%
import pymongo

# %%
 # package which enables us to connect to the MongoDB
dbConn = pymongo.MongoClient("mongodb://localhost:27017/")  # connecting to the locally running MongoDB Instance

# %%
dbname='mydemo'    #demoDB
db = dbConn[dbname] # connecting to the database named demoDB present in the mongoDB
# if the database is not present, it'll autoamtically create it.

# %%
# show all the databases
print(dbConn.list_database_names())
# Out:
# ['admin', 'config', 'local', 'mydemo', 'organization', 'pavandb']

# %%
# check if the databse exists in mongoDB
dblist=dbConn.list_database_names() # obtaining all the database names
db_name='mydemo'

if dblist.index(db_name)==-1:
    print ("This Databse doesn't exist")
else:
    print ("This Databse exists")
# Out:
# This Databse exists

# %%
# connecting to a collection--- collections are analogous to tables
collection_name='mytable'      #  mongo_demo
collection=db[collection_name]  # connectig to the collection itself present in the database.

# %%
# cheking if a collection exists
if collection_name in db.list_collection_names():
    print("The collection exists.")
else:
    print("The collection doesn't exist.")
# Out:
# The collection exists.

# %% [markdown]
# #### 1. inserting row into the collection

# %%
my_row = {'Serial No': '8143',
 'GRE Score': '125',
 'TOEFL Score': '682',
 'University Rating': '4',
 'SOP': '4.5',
 'LOR': '4.5',
 'CGPA': '9.65',
 'Research': '1',
 'Chance of Admit': '0.92'}    # creating key value pairs for inserting into the DB

# %%
x = collection.insert_one(my_row)  # inserting record into the collection

# %%
print(x.inserted_id) # printing the unique id for insert
# Out:
# 6083ebf47d549ed92556ede4

# %% [markdown]
# #### inserting multiple rows once

# %%
my_rows = [
{'Serial No': '9997',
 'GRE Score': '337',
 'TOEFL Score': '118',
 'University Rating': '4',
 'SOP': '4.5',
 'LOR': '4.5',
 'CGPA': '9.65',
 'Research': '1',
 'Chance of Admit': '0.92'},
  {
    'Serial No': '9996',
 'GRE Score': '336',
 'TOEFL Score': '118',
 'University Rating': '4',
 'SOP': '4.5',
 'LOR': '4.5',
 'CGPA': '9.6',
 'Research': '0',
 'Chance of Admit': '0.92'},
  {
    'Serial No': '9995',
 'GRE Score': '337',
 'TOEFL Score': '118',
 'University Rating': '4',
 'SOP': '4.5',
 'LOR': '4.5',
 'CGPA': '9.5',
 'Research': '1',
 'Chance of Admit': '0.92'},
  {
    'Serial No': '9994',
 'GRE Score': '334',
 'TOEFL Score': '119',
 'University Rating': '4',
 'SOP': '4.5',
 'LOR': '4.5',
 'CGPA': '9.4',
 'Research': '1',
 'Chance of Admit': '0.92'},
  {
    'Serial No': '9993',
 'GRE Score': '337',
 'TOEFL Score': '118',
 'University Rating': '4',
 'SOP': '4.5',
 'LOR': '4.5',
 'CGPA': '9.65',
 'Research': '1',
 'Chance of Admit': '0.92'}

]# creating key value pairs for inserting into the DB

# %%
# inserting records into the collection 
x = collection.insert_many(my_rows)

# %%
# printing the unique id for insert
print(x.inserted_ids)
# Out:
# [ObjectId('6083ecc47d549ed92556edea'), ObjectId('6083ecc47d549ed92556edeb'), ObjectId('6083ecc47d549ed92556edec'), ObjectId('6083ecc47d549ed92556eded'), ObjectId('6083ecc47d549ed92556edee')]

# %% [markdown]
# #### 2. retieving all the records from collection

# %%
result= collection.find({})               #  <pymongo.cursor.Cursor at 0x1affd90c2e8>
result[3]                              # printing the third record
# Out:
# {'_id': ObjectId('5ec11286822f1e88aa0007ad'),
#  'Serial No': '9123',
#  'GRE Score': '420',
#  'TOEFL Score': '540',
#  'University Rating': '3',
#  'SOP': '4.2',
#  'LOR': '3.9',
#  'CGPA': '8.9',
#  'chance of admit': '0.7'}

# %% [markdown]
# whenever we are calling the find() method, if we have too many rows/records in the table, then we'll get too many responses for that which might overwhelm the application. To overcome this scenario, we have a way in mongoDB to have an upper limit on the number of rows returned.
#
# It is called the **limit()** method.

# %%
# printing only the five rows
result_total= collection.find({}).limit(5)
for res in result_total:
    print(res)
# Out:
# {'_id': ObjectId('5ec11152822f1e88aa0007aa'), 'Serial No': '5593', 'GRE Score': '323', 'TOEFL Score': '120', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.9'}
# {'_id': ObjectId('5ec11286822f1e88aa0007ab'), 'Serial No': '1234', 'GRE Score': '326', 'TOEFL Score': '110', 'University Rating': '3.2', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.89'}
# {'_id': ObjectId('5ec11286822f1e88aa0007ac'), 'Serial No': '4568', 'GRE Score': '100', 'TOEFL Score': '124', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.91'}
# {'_id': ObjectId('5ec11286822f1e88aa0007ad'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}
# {'_id': ObjectId('5ec112d7822f1e88aa0007ae'), 'Serial No': '1234', 'GRE Score': '326', 'TOEFL Score': '110', 'University Rating': '3.2', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.89'}

# %%
# retrieveing some columns
result_some= collection.find({}, {'GRE Score','TOEFL Score'}).limit(5)   # retrieveing two columns  and 5 records
# The second parameter in find() specifies which columns to choose
for res in result_some:
    print(res)
# Out:
# {'_id': ObjectId('5ec11152822f1e88aa0007aa'), 'GRE Score': '323', 'TOEFL Score': '120'}
# {'_id': ObjectId('5ec11286822f1e88aa0007ab'), 'GRE Score': '326', 'TOEFL Score': '110'}
# {'_id': ObjectId('5ec11286822f1e88aa0007ac'), 'GRE Score': '100', 'TOEFL Score': '124'}
# {'_id': ObjectId('5ec11286822f1e88aa0007ad'), 'GRE Score': '420', 'TOEFL Score': '540'}
# {'_id': ObjectId('5ec112d7822f1e88aa0007ae'), 'GRE Score': '326', 'TOEFL Score': '110'}

# %% [markdown]
# #### finding the rows satisfying a given criteria

# %%
my_db_query={'GRE Score':'337'}
# printing all the rows where GRE Score is 337
result_GRE= collection.find(my_db_query)
for res in result_GRE:
    print(res)
# Out:
# {'_id': ObjectId('6083ec137d549ed92556ede5'), 'Serial No': '9997', 'GRE Score': '337', 'TOEFL Score': '118', 'University Rating': '4', 'SOP': '4.5', 'LOR': '4.5', 'CGPA': '9.65', 'Research': '1', 'Chance of Admit': '0.92'}
# {'_id': ObjectId('6083ec137d549ed92556ede7'), 'Serial No': '9995', 'GRE Score': '337', 'TOEFL Score': '118', 'University Rating': '4', 'SOP': '4.5', 'LOR': '4.5', 'CGPA': '9.5', 'Research': '1', 'Chance of Admit': '0.92'}
# {'_id': ObjectId('6083ec137d549ed92556ede9'), 'Serial No': '9993', 'GRE Score': '337', 'TOEFL Score': '118', 'University Rating': '4', 'SOP': '4.5', 'LOR': '4.5', 'CGPA': '9.65', 'Research': '1', 'Chance of Admit': '0.92'}
# {'_id': ObjectId('6083ecc47d549ed92556edea'), 'Serial No': '9997', 'GRE Score': '337', 'TOEFL Score': '118', 'University Rating': '4', 'SOP': '4.5', 'LOR': '4.5', 'CGPA': '9.65', 'Research': '1', 'Chance of Admit': '0.92'}
# {'_id': ObjectId('6083ecc47d549ed92556edec'), 'Serial No': '9995', 'GRE Score': '337', 'TOEFL Score': '118', 'University Rating': '4', 'SOP': '4.5', 'LOR': '4.5', 'CGPA': '9.5', 'Research': '1', 'Chance of Admit': '0.92'}
# {'_id': ObjectId('6083ecc47d549ed92556edee'), 'Serial No': '9993', 'GRE Score': '337', 'TOEFL Score': '118', 'University Rating': '4', 'SOP': '4.5', 'LOR': '4.5', 'CGPA': '9.65', 'Research': '1', 'Chance of Admit': '0.92'}

# %%
my_db_query={'GRE Score':{'$gt':'337'}}
# printing all the rows where GRE Score is greaterthan 330
result_GRE= collection.find(my_db_query)
for res in result_GRE:
    print(res)
# Out:
# {'_id': ObjectId('5ec11286822f1e88aa0007ad'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}
# {'_id': ObjectId('5ec112d7822f1e88aa0007b0'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}
# {'_id': ObjectId('5ec1137e822f1e88aa0007b3'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}

# %% [markdown]
# #### we can sort the above results as well, this has been sorted in ascending order

# %%
result_GRE= collection.find(my_db_query).sort('GRE Score')
for res in result_GRE:
    print(res)
# Out:
# {'_id': ObjectId('5ec11286822f1e88aa0007ad'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}
# {'_id': ObjectId('5ec112d7822f1e88aa0007b0'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}
# {'_id': ObjectId('5ec1137e822f1e88aa0007b3'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}

# %% [markdown]
# #### we can sort the above results in descending order

# %%
result_GRE= collection.find(my_db_query).sort('GRE Score',-1)
for res in result_GRE:
    print(res)
# Out:
# {'_id': ObjectId('5ec11286822f1e88aa0007ad'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}
# {'_id': ObjectId('5ec112d7822f1e88aa0007b0'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}
# {'_id': ObjectId('5ec1137e822f1e88aa0007b3'), 'Serial No': '9123', 'GRE Score': '420', 'TOEFL Score': '540', 'University Rating': '3', 'SOP': '4.2', 'LOR': '3.9', 'CGPA': '8.9', 'chance of admit': '0.7'}

# %% [markdown]
# #### 3. Deleting records from mongo DB:

# %%
# finding the rows satisfying a given criteria
my_db_query={'GRE Score':'337'}
x=collection.delete_one(my_db_query) # the deletion step
print(x.deleted_count)
# Out:
# 1

# %% [markdown]
# We have succesfully deleted one row/record from the collection.
#
# Similarly, for deleting multiple rows, we can use **collection.delete_many(my_deb_query)**
#
# For deleting all documents of a collection, we can use **collection.delete_many({})**

# %%
# For dropping an entire collection
collection_to_drop=db['test_collection'] # drops the entire collection named 'test collection'
collection_to_drop.drop()

# %%
# updating the values present in collection

update_criteria={'GRE Score':'340'}
new_values= { "$set": { "GRE Score": "350" } }

x = collection.update_many(update_criteria, new_values)

print(x.modified_count)
# Out:
# 0

# %% [markdown]
# We have updated the nine columns with GRE Score 340 with GRE Score 350.
#
# Similarly, we can update only one row by using the function **update_one(update_criteria, new_values)**

# %% [markdown]
# - if you want to import any json or csv file
# - click on "collection"

# %% [markdown]
# - create collection('table')
# - click on "mycoll2" and add documents
